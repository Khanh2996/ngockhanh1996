# %% [markdown]
# # Mã giả & Lưu đồ giải thuật
#
# ### Lập trình
#
# Lập trình là gì?

# %% [markdown]
# Lập trình là đưa ra các câu lệnh để máy tính thực hiện
# Khi đưa ra câu lênh A và câu lệnh B thì câu lệnh A sẽ được thực hiện trước

# %% [markdown]
# ### Thuật toán
#
# Thuật toán là gì?

# %% [markdown]
# Thuật toán là những câu lệnh được đưa ra để giải quyết một vấn đề nào đó

# %% [markdown]
# ### Mã gỉả
#
# #### Khái niệm:
#
# Mã giả được viết với ngôn ngữ tự nhiên một thuật toán nào đó dùng để giải quyết một vấn đề lập trình.
#
# Mã giả được quy ước chung theo từng nơi làm việc.
#
# Ví dụ:
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (món đó)
# Nếu (món đó còn):
#     Ta đặt món đó
# Ngược lại là:
#     Nếu(cơm sườn còn):
#         Ta đặt cơm sườn
#     Ngược lại:
#         Ta đi ngủ

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập ( a)
# Nếu (a>10):
#     In ra (a là số lớn hơn 10)
# Ngược lại:
#     In ra (a là số không lớn hơn 10)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (a)
# Nếu(a>0):
#     In ra (a là số dương)
# Ngược lại:
#         Nếu(a == 0)
#             In ra (a là số không âm không dương)
#         Ngược lại:
#             In ra (a là số âm)

# %% [markdown]
# ### Lưu đồ giải thuật
#
# Lưu đồ giải thuật là một thuật toán được biểu diễn với dạng lưu đồ
#
# Công cụ vẽ lưu đồ giải thuật: https://draw.io/
#
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Khi ta đói và thèm một món nào đó (nhập từ bàn phím), tiến hành đặt đồ ăn, nếu món ta thèm còn thì đặt đồ món đó, không còn thì đặt cơm sườn, không còn cơm sườn thì đi ngủ.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số đó có phải là số lớn hơn 10 không.
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>Đề bài:</b>
#
# Yêu cầu bài toán: Nhập vào một số a, kiểm tra xem số a là số âm hay số dương
#
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# ### Bài tập
#
# <b>Đề bài</b>
#
# Nhập vào nhiệt độ C, chuyển sang độ F rồi in ra màn hình
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (độ C)
# độ F = độ C * 1.8 + 32
#     In ra(độ F)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương tháng này, nếu lương tháng này nhiều hơn 2 triệu thì trừ đi 10% thuế, nếu không thì không trừ.
#
# Hãy tính và in ra lương thực nhận được
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (lương tháng này)
#     Nếu(lương tháng này > 2 triêu):
#         In ra (lương tháng này * 90%)
#     Ngược lại:
#         In ra(lương tháng này)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào lương thực nhận được tháng này, nếu lương ít hơn 10 triệu, đưa hết cho vợ, nếu lương nhiều hơn 10 triệu, vợ cho 10% lương
#
# Hãy tính và in ra màn hình phần lương mình được nhận
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập (lương tháng này)
#     Nếu(lương tháng này < 10.000.000):
#         In ra(đưa hết cho vợ)
#     ngược lại:
#         In ra(đưa cho vợ lương tháng này * 10%)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào số điểm văn và điểm toán, tính và in ra điểm trung bình, nếu điểm trung bình lớn hơn 8 thì in ra dòng chữ Học sinh giỏi, ngược lại thì in ra dòng chữ Không phải học sinh giỏi
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập(điển văn)
# Nhập(điểm toán)
#     Nếu((điểm văn + điểm toán)/2 > 8):
#         In ra(Học sinh giỏi)
#     ngược lại:
#         In ra(Không phải học sinh giỏi)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra xem số đó có chia hết cho 5 hay không
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập(a)
# Phần dư = số % 5
# Nếu (phần dư == 0):
#     in ra(đây là số chia hết cho 5)
#  ngược lại:
#      in ra(đây không là số chia hết cho 5)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào điểm số, nếu điểm số lớn hơn hoặc bằng 8, in ra dòng chữ Học sinh giỏi, nếu điểm số bé hơn 8 và lớn hơn hoặc bằng 6, in ra dòng chữ chữ học sinh Khá, ngược lại in ra dòng chữ Học sinh trung bình
#
# <b>Mã giả:</b>

# %% [markdown]
# Nhập(điểm)
#     Nếu(điểm >= 8):
#         In ra(học sinh giỏi)
#     Nếu(điểm < 8 and điển >= 6):
#         In ra(học sinh khá)
#     Nếu(điểm < 6):
#         In ra(học sinh trung bình)

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>

# %% [markdown]
# <b>Đề bài</b>
#
# Nhập vào một số, kiểm tra tính chẳn lẻ và số đó có lớn hơn 10 hay không. (in ra 4 trường hợp: chẳn lớn hơn 10, lẻ lớn hơn 10, chẳn bé hơn hoặc bằng 10, lẻ bé hơn hoặc bằng 10)
#
# <b>Mã giả:</b>

# %%
nhâp(a)
Nếu(a < 10 and a % 2 == 0):
    In ra(a là số chẵn nhỏ hơn 10)
ngược lại:
    In ra(a là số lẻ lớn hơn 10)
nếu(a > 10 and a % 2 == 1): 
    In ra(a là số chẵn lớn hơn 10)
ngược lại:
    In ra(a là số lẻ nhỏ hơn 10)
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_7064/1148226812.py", line 2
#     Nếu(a < 10 and a % 2 == 0):
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# <b>Lưu đồ giải thuật:</b>
